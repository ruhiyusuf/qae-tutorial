# %% [markdown]
# # Quantum Autoencoder (QAE) Tutorial
#
# In this notebook, we’ll walk through the implementation of a Quantum Autoencoder (QAE) using Qiskit.
# QAEs aim to compress quantum states by removing redundancy—preserving only essential quantum information.
#
# We will:
# - Define the variational ansatz
# - Build encoder/decoder architecture
# - Train to compress and decompress quantum states
# - Use the SWAP test to evaluate fidelity

# %% [markdown]
# # Step 1: Import Libraries and Set Up Sampler
#
# We use Qiskit’s Sampler primitive to run circuits and get expectation values.

# %%
! pip install --upgrade pip
! pip install matplotlib
! pip install jupyter
! pip install qiskit==1.4.3 
! pip install qiskit-machine-learning
! pip install pylatexenc
! pip show qiskit
# Out:
# Requirement already satisfied: pip in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (25.1.1)
# Requirement already satisfied: matplotlib in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: jupyter in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (1.1.1)
# Requirement already satisfied: notebook in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter) (7.4.3)
# Requirement already satisfied: jupyter-console in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter) (4.4.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (9.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (307)
# Requirement already satisfied: six>=1.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.24.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbconvert->jupyter) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbconvert->jupyter) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (4.13.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250516)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: qiskit==1.4.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (1.4.3)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (1.15.3)
# Requirement already satisfied: sympy>=1.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (1.14.0)
# Requirement already satisfied: dill>=0.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (4.13.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit==1.4.3) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from python-dateutil>=2.8.0->qiskit==1.4.3) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from stevedore>=3.0.0->qiskit==1.4.3) (6.1.1)
# Requirement already satisfied: setuptools in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit==1.4.3) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from sympy>=1.3->qiskit==1.4.3) (1.3.0)
# Requirement already satisfied: qiskit-machine-learning in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (0.8.2)
# Requirement already satisfied: qiskit>=1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (1.4.3)
# Requirement already satisfied: scipy>=1.4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (1.15.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (2.2.6)
# Requirement already satisfied: psutil>=5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (7.0.0)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (1.6.1)
# Requirement already satisfied: setuptools>=40.1 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (80.9.0)
# Requirement already satisfied: dill>=0.3.4 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit-machine-learning) (0.4.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit>=1.0->qiskit-machine-learning) (0.16.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit>=1.0->qiskit-machine-learning) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit>=1.0->qiskit-machine-learning) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit>=1.0->qiskit-machine-learning) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit>=1.0->qiskit-machine-learning) (4.13.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from qiskit>=1.0->qiskit-machine-learning) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=1.0->qiskit-machine-learning) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.0->qiskit-machine-learning) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (from sympy>=1.3->qiskit>=1.0->qiskit-machine-learning) (1.3.0)
# Requirement already satisfied: pylatexenc in c:\users\ruhiy\miniconda3\envs\qiskit_env\lib\site-packages (2.10)
# Name: qiskit
# Version: 1.4.3
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: C:\Users\ruhiy\miniconda3\envs\qiskit_env\Lib\site-packages
# Requires: dill, numpy, python-dateutil, rustworkx, scipy, stevedore, symengine, sympy, typing-extensions
# Required-by: qiskit-aer, qiskit-machine-learning

# %% [markdown]
# ### Test for successful installation of Qiskit and Qiskit Machine Learning Library // Probably going to delete

# %%
from qiskit.circuit.library import TwoLocal, ZZFeatureMap
from qiskit_machine_learning.optimizers import COBYLA
from qiskit_machine_learning.utils import algorithm_globals

from qiskit_machine_learning.algorithms import VQC
from qiskit_machine_learning.datasets import ad_hoc_data

import qiskit.primitives.backend_sampler_v2
seed = 1376
algorithm_globals.random_seed = seed

# Use ad hoc data set for training and test data
feature_dim = 2  # dimension of each data point
training_size = 20
test_size = 10

# training features, training labels, test features, test labels as np.ndarray,
# one hot encoding for labels
training_features, training_labels, test_features, test_labels = ad_hoc_data(
    training_size=training_size, test_size=test_size, n=feature_dim, gap=0.3
)

feature_map = ZZFeatureMap(feature_dimension=feature_dim, reps=2, entanglement="linear")
ansatz = TwoLocal(feature_map.num_qubits, ["ry", "rz"], "cz", reps=3)
vqc = VQC(
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=COBYLA(maxiter=100),
)
vqc.fit(training_features, training_labels)

score = vqc.score(test_features, test_labels)
print(f"Testing accuracy: {score:0.2f}")
# Out:
# Testing accuracy: 0.95

# %% [markdown]
# Import Quantum ML Libraries and initialize Sampler

# %%
import json
import time
import warnings

import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
from qiskit import ClassicalRegister, QuantumRegister
from qiskit import QuantumCircuit
from qiskit.circuit.library import RealAmplitudes
from qiskit.primitives import StatevectorSampler as Sampler
from qiskit.quantum_info import Statevector
from qiskit_machine_learning.optimizers import COBYLA
from qiskit_machine_learning.utils import algorithm_globals

from qiskit_machine_learning.circuit.library import RawFeatureVector
from qiskit_machine_learning.neural_networks import SamplerQNN

algorithm_globals.random_seed = 42
sampler = Sampler()

# %% [markdown]
# # Step 2: Define the Ansatz
#
# We define a variational ansatz based on RealAmplitudes. This provides parameterized RY rotations followed by CNOT entanglement layers.
# This circuit is used both for encoding and decoding, ensuring symmetry.

# %%
def ansatz(num_qubits):
    return RealAmplitudes(num_qubits, reps=5)
    # return RealAmplitudes(num_qubits, reps=5, entanglement = "linear") # changes the measurement order

num_qubits = 5
circ = ansatz(num_qubits)
circ.decompose().draw(output="mpl", style="clifford")

# %% [markdown]
# # Step 3: Construct the Autoencoder Circuit
#
# This function builds the complete autoencoder circuit:
# - Applies the variational encoder
# - Swaps the 'trash' qubits with a reference |0⟩ state using SWAP gates
# - Includes an auxiliary qubit for the SWAP test

# %%
def auto_encoder_circuit(num_latent, num_trash):
    qr = QuantumRegister(num_latent + 2 * num_trash + 1, "q")
    cr = ClassicalRegister(1, "c")
    circuit = QuantumCircuit(qr, cr)
    circuit.compose(ansatz(num_latent + num_trash), range(0, num_latent + num_trash), inplace=True)
    circuit.barrier()
    auxiliary_qubit = num_latent + 2 * num_trash
    # swap test
    circuit.h(auxiliary_qubit)
    for i in range(num_trash):
        circuit.cswap(auxiliary_qubit, num_latent + i, num_latent + num_trash + i)

    circuit.h(auxiliary_qubit)
    circuit.measure(auxiliary_qubit, cr[0])
    return circuit

num_latent = 3
num_trash = 2
circuit = auto_encoder_circuit(num_latent, num_trash)
circuit.draw(output="mpl", style="clifford")

# %%
def domain_wall(circuit, a, b):
    # Here we place the Domain Wall to qubits a - b in our circuit
    for i in np.arange(int(b / 2), int(b)):
        circuit.x(i)
    return circuit


domain_wall_circuit = domain_wall(QuantumCircuit(5), 0, 5)
domain_wall_circuit.draw("mpl", style="clifford")

# %%
ae = auto_encoder_circuit(num_latent, num_trash)
qc = QuantumCircuit(num_latent + 2 * num_trash + 1, 1)
qc = qc.compose(domain_wall_circuit, range(num_latent + num_trash))
qc = qc.compose(ae)
qc.draw(output="mpl", style="clifford")

# %%
# Here we define our interpret for our SamplerQNN
def identity_interpret(x):
    return x

qnn = SamplerQNN(
    circuit=qc,
    input_params=[],
    weight_params=ae.parameters,
    interpret=identity_interpret,
    output_shape=2,
    sampler=sampler,
)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.

# %% [markdown]
# # Step 4: Define the Cost Function
#
# We measure the auxiliary qubit.
# If the result is close to |0⟩, the two states are likely identical.
# Cost = 2 * L / M, where:
# - L = number of 1s measured on the auxiliary qubit
# - M = total number of measurements

# %%
def cost_func_domain(params_values):
    probabilities = qnn.forward([], params_values)
    # we pick a probability of getting 1 as the output of the network
    cost = np.sum(probabilities[:, 1])  

    # plotting part
    clear_output(wait=True)
    objective_func_vals.append(cost)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()
    return cost

# %% [markdown]
# # Step 5: Simulate and Evaluate
#
# Here we run the circuit multiple times, collect the results from the sampler, and compute fidelity.
# This helps us quantify how well the QAE preserved the input.

# %% [markdown]
# ## Choosing a Loss Function and Optimizer in Quantum Machine Learning
#
# In variational quantum algorithms like the Quantum Autoencoder, training involves minimizing a loss function by adjusting gate parameters (the quantum equivalent of neural network weights). This is done using a classical optimizer.
#
#
# ### Loss Functions
#
# | Loss Function          | Use Case                                                                 |
# |------------------------|--------------------------------------------------------------------------|
# | Fidelity Loss          | Measures similarity between output and target states: `1 - fidelity`     |
# | Swap Test Loss         | Indirectly computes fidelity via interference using an ancilla qubit     |
# | Expectation Value      | For energy minimization (e.g., VQE), minimize ⟨ψ(θ)|H|ψ(θ)⟩               |
# | Cross-Entropy Loss     | Used in classification problems with QNN classifiers                     |
#
# In this tutorial, we use Swap Test Fidelity Loss, which compares the reconstructed output with a reference using an ancilla qubit and controlled SWAP gates.
#
#
# ### Classical Optimizers
#
# | Optimizer    | Type             | Requires Gradient | Best For                                            |
# |--------------|------------------|--------------------|------------------------------------------------------|
# | COBYLA       | Constrained       | No                 | Noisy or small-scale quantum circuits (good default) |
# | SPSA         | Probabilistic     | No                 | Large parameter spaces, works well under noise       |
# | L-BFGS-B     | Gradient-based    | Yes                | Smooth, differentiable loss (simulator only)         |
# | ADAM         | Gradient-based    | Yes                | Hybrid QNNs using TorchConnector or PennyLane        |
#
#
# ### When to Use What
#
# - COBYLA → Simple circuits, low noise, fast prototyping
# - SPSA → Noisy devices, many parameters, robust but slower
# - L-BFGS-B / ADAM → Simulated environments with access to gradients
# - Avoid gradient-based optimizers on real hardware without explicit support
#
# Tip: Always plot the loss vs. iteration curve to check for convergence and optimizer stability.

# %%
opt = COBYLA(maxiter=150)
initial_point = algorithm_globals.random.random(ae.num_parameters)

objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()
opt_result = opt.minimize(cost_func_domain, initial_point)
elapsed = time.time() - start

print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 21.03 seconds

# %%
test_qc = QuantumCircuit(num_latent + num_trash)
test_qc = test_qc.compose(domain_wall_circuit)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc = test_qc.compose(ansatz_qc)
test_qc.barrier()
test_qc.reset(4)
test_qc.reset(3)
test_qc.barrier()
test_qc = test_qc.compose(ansatz_qc.inverse())

test_qc.draw(output="mpl", style="clifford")

# %%
test_qc = test_qc.assign_parameters(opt_result.x)

# %%
domain_wall_state = Statevector(domain_wall_circuit).data
output_state = Statevector(test_qc).data

fidelity = np.sqrt(np.dot(domain_wall_state.conj(), output_state) ** 2)
print("Fidelity of our Output State with our Input State: ", fidelity.real)
# Out:
# Fidelity of our Output State with our Input State:  0.9448786444763668

# %% [markdown]
# # Example of using Quantum Autoencoders for Image / Digital Compression

# %%
def zero_idx(j, i):
    # Index for zero pixels
    return [
        [i, j],
        [i - 1, j - 1],
        [i - 1, j + 1],
        [i - 2, j - 1],
        [i - 2, j + 1],
        [i - 3, j - 1],
        [i - 3, j + 1],
        [i - 4, j - 1],
        [i - 4, j + 1],
        [i - 5, j],
    ]


def one_idx(i, j):
    # Index for one pixels
    return [[i, j - 1], [i, j - 2], [i, j - 3], [i, j - 4], [i, j - 5], [i - 1, j - 4], [i, j]]


def get_dataset_digits(num, draw=True):
    # Create Dataset containing zero and one
    train_images = []
    train_labels = []
    for i in range(int(num / 2)):
        # First we introduce background noise
        empty = np.array([algorithm_globals.random.uniform(0, 0.1) for i in range(32)]).reshape(
            8, 4
        )

        # Now we insert the pixels for the one
        for i, j in one_idx(2, 6):
            empty[j][i] = algorithm_globals.random.uniform(0.9, 1)
        train_images.append(empty)
        train_labels.append(1)
        if draw:
            plt.title("This is a One")
            plt.imshow(train_images[-1])
            plt.show()

    for i in range(int(num / 2)):
        empty = np.array([algorithm_globals.random.uniform(0, 0.1) for i in range(32)]).reshape(
            8, 4
        )

        # Now we insert the pixels for the zero
        for k, j in zero_idx(2, 6):
            empty[k][j] = algorithm_globals.random.uniform(0.9, 1)

        train_images.append(empty)
        train_labels.append(0)
        if draw:
            plt.imshow(train_images[-1])
            plt.title("This is a Zero")
            plt.show()

    train_images = np.array(train_images)
    train_images = train_images.reshape(len(train_images), 32)

    for i in range(len(train_images)):
        sum_sq = np.sum(train_images[i] ** 2)
        train_images[i] = train_images[i] / np.sqrt(sum_sq)

    return train_images, train_labels


train_images, __ = get_dataset_digits(2)

# %%
num_latent = 3
num_trash = 2

fm = RawFeatureVector(2 ** (num_latent + num_trash))

ae = auto_encoder_circuit(num_latent, num_trash)

qc = QuantumCircuit(num_latent + 2 * num_trash + 1, 1)
qc = qc.compose(fm, range(num_latent + num_trash))
qc = qc.compose(ae)

qc.draw(output="mpl", style="clifford")

# %%
def identity_interpret(x):
    return x


qnn = SamplerQNN(
    circuit=qc,
    input_params=fm.parameters,
    weight_params=ae.parameters,
    interpret=identity_interpret,
    output_shape=2,
    sampler=sampler,
)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.

# %%
def cost_func_digits(params_values):
    probabilities = qnn.forward(train_images, params_values)
    cost = np.sum(probabilities[:, 1]) / train_images.shape[0]

    # plotting part
    clear_output(wait=True)
    objective_func_vals.append(cost)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

    return cost

# %%
# load pre-existing weights, only if you have access to them
with open("12_qae_initial_point.json", "r") as f:
    initial_point = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 2
#       1 # load pre-existing weights, only if you have access to them
# ----> 2 with open("12_qae_initial_point.json", "r") as f:
#       3     initial_point = json.load(f)
#
# File c:\Users\ruhiy\miniconda3\envs\qiskit_env\Lib\site-packages\IPython\core\interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '12_qae_initial_point.json'

# %%
opt = COBYLA(maxiter=150)

objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()
opt_result = opt.minimize(fun=cost_func_digits, x0=initial_point)
elapsed = time.time() - start
print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 22.68 seconds

# %%
# Test
test_qc = QuantumCircuit(num_latent + num_trash)
test_qc = test_qc.compose(fm)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc = test_qc.compose(ansatz_qc)
test_qc.barrier()
test_qc.reset(4)
test_qc.reset(3)
test_qc.barrier()
test_qc = test_qc.compose(ansatz_qc.inverse())

# sample new images
test_images, test_labels = get_dataset_digits(2, draw=False)
for image, label in zip(test_images, test_labels):
    original_qc = fm.assign_parameters(image)
    original_sv = Statevector(original_qc).data
    original_sv = np.reshape(np.abs(original_sv) ** 2, (8, 4))

    param_values = np.concatenate((image, opt_result.x))
    output_qc = test_qc.assign_parameters(param_values)
    output_sv = Statevector(output_qc).data
    output_sv = np.reshape(np.abs(output_sv) ** 2, (8, 4))

    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(original_sv)
    ax1.set_title("Input Data")
    ax2.imshow(output_sv)
    ax2.set_title("Output Data")
    plt.show()

# %% [markdown]
# # Conclusion
#
# - Quantum autoencoders compress quantum information efficiently.
# - Using SWAP tests, we can quantify information loss.
# - This QAE architecture is small, but the concept can scale to larger quantum systems for real-world tasks like quantum image compression or quantum chemistry.
#
# You can try changing the ansatz depth or number of latent qubits to see how it affects compression quality!
